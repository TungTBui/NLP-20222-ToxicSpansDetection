# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 43.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.3 MB/s eta 0:00:00
# ...

# %%
import torch
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append("/content/drive/MyDrive/NLP 20222/src")

# %%
from Model.BiLSTM_CRF.predict_lstm import predict as predict_lstm
from Model.XLM_RoBERTa.predict_bert import predict as predict_bert

# %%
checkpoint = torch.load('/content/drive/MyDrive/NLP 20222/xlm_roberta_pretrained/checkpoint_xlm_base.pth.tar')
model_xlm_base = checkpoint['model']
print("XLM_R_Base Loaded")

checkpoint = torch.load('/content/drive/MyDrive/NLP 20222/xlm_roberta_pretrained/checkpoint_xlm_large.pth.tar')
model_xlm_large = checkpoint['model']
print("XLM_R_Large Loaded")

checkpoint = torch.load('/content/drive/MyDrive/NLP 20222/PhoBERT_pretrained/checkpoint_phobertbase.pth.tar')
model_phobert_base = checkpoint['model']
print("PhoBERT_Base Loaded")

checkpoint = torch.load('/content/drive/MyDrive/NLP 20222/PhoBERT_pretrained/checkpoint_phobertlarge.pth.tar')
model_phobert_large = checkpoint['model']
print("PhoBERT_Large Loaded")
# Out:
# XLM_R_Base Loaded
# XLM_R_Large Loaded
# PhoBERT_Base Loaded
# PhoBERT_Large Loaded

# %% [markdown]
# ## Predict with PhoBERT and XLM_R

# %%
#Example
text = "Võ thuật gì, toàn tào lao giật tít lừa đảo"
t, ibo_, spans = predict_bert(model_xlm_large, text)
print("Original Text:", text)
print("Toxic Spans Prediction: ", spans)
# Out:
# ...
# Running Prediction:   0%|          | 0/2 [00:00<?, ?it/s]
# Original Text: Võ thuật gì, toàn tào lao giật tít lừa đảo
# Toxic Spans Prediction:  ['tào', 'lao', 'lừa']

# %%
#Example
text = "Võ thuậtgì, toàn tào lao giật tít lừa đảo"
t, ibo_, spans = predict_bert(model_phobert_large, text)
print("Original Text:", text)
print("Toxic Spans Prediction: ", spans)
# Out:
# ...
# Running Prediction:   0%|          | 0/2 [00:00<?, ?it/s]
# Original Text: Võ thuậtgì, toàn tào lao giật tít lừa đảo
# Toxic Spans Prediction:  ['tào', 'lao', 'lừa']

# %% [markdown]
# ## Predict with BiLSTM-CRF

# %%
#Example
model_lstm_path = "/content/drive/MyDrive/NLP 20222/BiLSTM_CRF_pretrained"
text = "Võ thuật gì, toàn tào lao giật tít lừa đảo"
spans = predict_lstm(model_lstm_path, text)
print("Original Text:", text)
print("Toxic Spans Prediction: ", spans)
# Out:
# Original Text: Võ thuật gì, toàn tào lao giật tít lừa đảo
# Toxic Spans Prediction:  ['Võ', 'toàn', 'giật', 'đảo']
